# %% [markdown]
# # Creating an Embedding
#
# We crop the images using Birme and process to train an embedding :
#
# ## Process
# <img src='images/Capture.PNG' width=50%>
# <img src='images/Capture1.PNG' width=50%>
# <img src='images/Capture2.PNG' width=50%>
# <img src='images/Capture3.PNG' width=50%>
# <img src='images/Capture4.PNG' width=50%>
# <img src='images/Capture5.PNG' width=50%>
# <img src='images/Capture9.PNG' width=50%>
# <img src='images/Capture10.PNG' width=50%>
# <img src='images/Capture6.PNG' width=50%>
# <img src='images/Capture7.PNG' width=50%>
# <img src='images/Capture8.PNG' width=50%>
#
#
# ## Prompts after trying 10 other ones
#
# Positive
# alpictw - man, pencil sketch portrait  canvas, blank and white, bald asian, wearing glasses, smiling, age thirty years old, round face, medium chubby man, emphasize brush stroke painting, hatching, draw, canvas texture
#
# Negative
# beard, smooth painting, soft traces, soft texture, realistic, professional paint
#
# Positive
# alpictw - man, pencil sketch portrait  canvas, grayscale, wearing glasses, smiling, age fifty years old, round face, man, emphasize brush stroke painting, hatching, draw, canvas texture, detailed shadows, contrasting colors, heavily canvas texture, brush with stiffer bristles
#
# Negative
# beard, smooth painting, soft traces, soft texture, realistic, professional paint, light, ultra-detailed, photo, undetailed hair, detailed face, lots of facial expression lines
#
# Positive
# alpictw - man, pencil sketch portrait  canvas, grayscale, wearing glasses, smiling, age fifty years old, round face, man, emphasize brush stroke painting, hatching, draw, canvas texture, detailed shadows, contrasting colors, undefined expression lines
#
# Negative
# beard, smooth painting,  soft texture, realistic, professional paint, light, ultra-detailed, photo, undetailed hair, detailed face, lots of facial expression lines, strong traces, distinctiveness, contrasting lines
#
# # Good Images
#
# <img src='images/Capture20good.PNG' width=50%>
# <img src='images/Capturecanvasgood.PNG' width=50%>
# <img src='images/Capture13.png' width=50%>
# <img src='images/Capture14.png' width=50%>
# <img src='images/Capture16.png' width=50%>
# <img src='images/Capture17.png' width=50%>
# <img src='images/Capture22.png' width=50%>
# <img src='images/Capture19.png' width=50%>
#
# # Look this
# alpictwo, man, pencil sketch portrait canvas, grayscale, wearing glasses, smiling, age thirty years old, round face, hatching, draw, canvas texture, detailed shadows, contrasting colors, undefined expression lines, emphasize (coarse charcoal sketch:1.2) painting
#
#
# Prompt for the poster
# man, pencil sketch portrait canvas, grayscale, smiling, age thirty years old, round face, hatching, draw, canvas texture, detailed shadows, contrasting colors, undefined expression lines, emphasize coarse charcoal sketch painting,
#
# Negative: lines sharply defined, realistic, light, ultra-detailed, photo, undetailed hair, lots of facial expression lines, strong traces, distinctiveness, contrasting lines
#
#
# Kind of good 12/01/2023
#
#  alpictwo, man, pencil sketch portrait canvas, facing frontward, grayscale, wearing glasses, smiling, age sixty years old, round face, hatching, draw, canvas texture, detailed shadows, contrasting colors, undefined expression lines, emphasize coarse charcoal sketch painting, facial features with shading, painting neatly groomed fluffy hair with a side part to the right, sense of depth, monochromatic, blend naturally into the shadows
#
#  sharp boundaries, lines sharply defined, realistic, light, ultra-detailed, photo, undetailed hair, lots of facial expression lines, strong traces, distinctiveness, contrasting lines, facial features outlined with hard lines, tie, color
#
#  alpictwo, man, seventy years old, detailed pencil sketch, realistic painting human portrait, focus on expression, facial features with shading, sense of depth and form, eyes convey emotion, hair with texture and blend naturally into the shadows and highlights of the face, pencil strokes, hatching and cross-hatching, three-dimensional effect, overall sketch evoke a lifelike, appearance with a touch of ambiguity, canvas texture, monochromatic, grayscale, wearing glasses, smiling, facing forward
#
#  focused on precision, facial features outlined with hard lines, sharp boundaries, realistic photo, lots of color
